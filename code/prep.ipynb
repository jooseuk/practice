# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
! git clone "https://github.com/jooseuk/practice.git"
# Out:
# Cloning into 'practice'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 182 (delta 2), reused 1 (delta 1), pack-reused 179 (from 2)
# Receiving objects: 100% (182/182), 308.22 MiB | 13.47 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Updating files: 100% (12/12), done.
# fatal: cannot exec '/content/drive/MyDrive/Colab Notebooks/practice/.git/hooks/post-checkout': Permission denied
# Encountered 1 file(s) that should have been pointers, but weren't:
# 	download/dataset.zip

# %%
# 데이터셋 압축 풀기
import os, zipfile
file_name = "/content/drive/MyDrive/Colab Notebooks/practice/download/dataset.zip"
output_dir = "/content/drive/MyDrive/Colab Notebooks/practice/download/dataset"

os.makedirs(output_dir, exist_ok=True)
with zipfile.ZipFile(file_name, 'r') as zip_ref:
    zip_ref.extractall(output_dir)
