# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
! git clone "https://github.com/jooseuk/hemp.git"
# Out:
# Cloning into 'hemp'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 112 (delta 7), reused 5 (delta 1), pack-reused 90 (from 2)
# Receiving objects: 100% (112/112), 218.24 MiB | 14.70 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Updating files: 100% (7/7), done.

# %%
import os, zipfile

file_name = "/content/drive/MyDrive/Colab Notebooks/hemp/download/dataset.zip"
output_dir = "/content/drive/MyDrive/Colab Notebooks/hemp/download/dataset"

os.makedirs(output_dir, exist_ok=True)
with zipfile.ZipFile(file_name, 'r') as zip_ref:
    zip_ref.extractall(output_dir)
