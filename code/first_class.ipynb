# %% [markdown]
# **회귀분석실습**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import statsmodels as sm
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 불러오기
boston = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/hemp/download/Boston_house.csv")

boston
# Out:
#       AGE       B     RM     CRIM     DIS  INDUS  LSTAT    NOX  PTRATIO  RAD  \
# 0    65.2  396.90  6.575  0.00632  4.0900   2.31   4.98  0.538     15.3    1
# 1    78.9  396.90  6.421  0.02731  4.9671   7.07   9.14  0.469     17.8    2
# 2    61.1  392.83  7.185  0.02729  4.9671   7.07   4.03  0.469     17.8    2
# 3    45.8  394.63  6.998  0.03237  6.0622   2.18   2.94  0.458     18.7    3
# 4    54.2  396.90  7.147  0.06905  6.0622   2.18   5.33  0.458     18.7    3
# ..    ...     ...    ...      ...     ...    ...    ...    ...      ...  ...
# 501  69.1  391.99  6.593  0.06263  2.4786  11.93   9.67  0.573     21.0    1
# 502  76.7  396.90  6.120  0.04527  2.2875  11.93   9.08  0.573     21.0    1
# 503  91.0  396.90  6.976  0.06076  2.1675  11.93   5.64  0.573     21.0    1
# 504  89.3  393.45  6.794  0.10959  2.3889  11.93   6.48  0.573     21.0    1
# 505  80.8  396.90  6.030  0.04741  2.5050  11.93   7.88  0.573     21.0    1
#
#        ZN  TAX  CHAS  Target
# ...

# %%
# 상관 관계 행렬
boston_corr = boston.corr()

# 히트맵
plt.figure(figsize=(10, 10))
sns.set(font_scale=0.8)
sns.heatmap(boston_corr, annot=True, cbar=False)
plt.show()

# %%
corr_matrix = boston.corr()
corr_matrix["Target"].sort_values(ascending=False)
# Out:
# Target     1.000000
# RM         0.695360
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: Target, dtype: float64

# %%
import io
import pandas as pd
from sklearn.metrics import mean_squared_error

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/hemp/download/Boston_house.csv')

from sklearn.model_selection import train_test_split

x = data[['LSTAT']]
y = data[['Target']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3)

from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_predict = mlr.predict(x_test)
print("독립변수 1개")
print(mlr.score(x_train, y_train))

mse = mean_squared_error(y_test, y_predict)
rmse = mse ** 0.5

print("RMSE:", rmse)
# Out:
# 독립변수 1개
# 0.5416988326206176
# RMSE: 5.952347675036191

# %%
import io
import pandas as pd
from sklearn.metrics import mean_squared_error

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/hemp/download/Boston_house.csv')

from sklearn.model_selection import train_test_split

x = data[['LSTAT', 'RM']]
y = data[['Target']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3)

from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_predict = mlr.predict(x_test)

print(mlr.score(x_train, y_train))

mse = mean_squared_error(y_test, y_predict)
rmse = mse ** 0.5

print("RMSE:", rmse)
# Out:
# 0.635356180129456
# RMSE: 5.279750681124748

# %%
import io
import pandas as pd
from sklearn.metrics import mean_squared_error

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/hemp/download/Boston_house.csv')

from sklearn.model_selection import train_test_split

x = data[['AGE', 'B', 'RM', 'CRIM', 'DIS', 'INDUS', 'LSTAT', 'NOX', 'PTRATIO', 'RAD', 'ZN', 'TAX', 'CHAS']]
y = data[['Target']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3)

from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_predict = mlr.predict(x_test)

print("독립변수 여러 개")
print(mlr.score(x_train, y_train))

mse = mean_squared_error(y_test, y_predict)
rmse = mse ** 0.5

print("RMSE:", rmse)
# Out:
# 독립변수 여러 개
# 0.7607567348164846
# RMSE: 5.3736085817996635

# %% [markdown]
# **openCV 실습**

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow
import sys

# 이미지 업로드
uploaded = cv2.imread('/content/drive/MyDrive/Colab Notebooks/hemp/download/lettuce.jpg')

if uploaded is None:
    print('Image load failed!')
    sys.exit()

cv2_imshow(uploaded)
# Out:
# <PIL.Image.Image image mode=RGB size=204x136>

# %%
gray_image = cv2.cvtColor(uploaded, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=204x136>

# %% [markdown]
# 비파과적 분석방법 소개

# %% [markdown]
# > 인용구 추가

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow
import sys
uploaded = cv2.imread('/content/drive/MyDrive/Colab Notebooks/hemp/download/lettuce.jpg')

if uploaded is None:
    print('Image load failed!')
    sys.exit()

cv2_imshow(uploaded)
# Out:
# <PIL.Image.Image image mode=RGB size=204x136>

# %%
import cv2
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


# 이미지 전처리
image = cv2.cvtColor(uploaded, cv2.COLOR_BGR2RGB)
image = image.reshape((image.shape[0] * image.shape[1], 3))  # height, width 통합



k = 2
clt = KMeans(n_clusters=k)
clt.fit(image)

def centroid_histogram(clt):
    numLabels = np.arange(0, len(np.unique(clt.labels_)) + 1)
    (hist, _) = np.histogram(clt.labels_, bins=numLabels)
    hist = hist.astype("float")
    hist /= hist.sum()
    return hist

hist = centroid_histogram(clt)

def plot_colors(hist, centroids):
    bar = np.zeros((50, 300, 3), dtype="uint8")
    startX = 0
    for (percent, color) in zip(hist, centroids):
        endX = startX + (percent * 300)
        cv2.rectangle(bar, (int(startX), 0), (int(endX), 50),
                      color.astype("uint8").tolist(), -1)
        startX = endX
    return bar

bar = plot_colors(hist, clt.cluster_centers_)

plt.figure(figsize=(8, 4))
plt.axis("off")
plt.imshow(bar)
plt.show()

# %% [markdown]
# 퀴즈 " 흰색 배경이 포함되어 있어서 제대로 된 분류가 되질 않네요. 어떻게 해야할까요?"

# %%
import cv2
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# 이미지 전처리
image = cv2.cvtColor(uploaded, cv2.COLOR_BGR2RGB)
image = image.reshape((image.shape[0] * image.shape[1], 3))  # height, width 통합
image = np.delete(image, np.where(np.all(image > [245, 245, 245], axis=1)), axis=0)

k = 2
clt = KMeans(n_clusters=k)
clt.fit(image)

def centroid_histogram(clt):
    numLabels = np.arange(0, len(np.unique(clt.labels_)) + 1)
    (hist, _) = np.histogram(clt.labels_, bins=numLabels)
    hist = hist.astype("float")
    hist /= hist.sum()
    return hist

hist = centroid_histogram(clt)

def plot_colors(hist, centroids):
    bar = np.zeros((50, 300, 3), dtype="uint8")
    startX = 0
    for (percent, color) in zip(hist, centroids):
        endX = startX + (percent * 300)
        cv2.rectangle(bar, (int(startX), 0), (int(endX), 50),
                      color.astype("uint8").tolist(), -1)
        startX = endX
    return bar

bar = plot_colors(hist, clt.cluster_centers_)

plt.figure(figsize=(8, 4))
plt.axis("off")
plt.imshow(bar)
plt.show()

# %%
# 필요한 모듈 임포트
from yellowbrick.cluster import SilhouetteVisualizer

# k값 범위 설정
k_range = range(2, 5)

# 각 k값에 대한 시각화 및 실루엣 지수 출력
for k in k_range:
    clt = KMeans(n_clusters=k)
    visualizer = SilhouetteVisualizer(clt, colors='yellowbrick')
    visualizer.fit(image)
    print(f"K = {k}, Silhouette Score: {visualizer.silhouette_score_: .4f}")
    visualizer.show()
# Out:
# K = 2, Silhouette Score:  0.5594
# K = 3, Silhouette Score:  0.5230
# K = 4, Silhouette Score:  0.4555
